# %% [markdown]
# ### Representation - Commons votes
#
# ### Links
#
# [UK Parliament Developer Hub](https://developer.parliament.uk/)

# %%
import pandas as pd
import requests
import urllib
import time

# %%
url_base = "https://members-api.parliament.uk/api"

# %% [markdown]
# ## 1. Data

# %% [markdown]
# ### 1.1 Members

# %%
# Members - Medway
path_members = 'data/representation/members.json'
df_members = (
    pd.read_json(path_members)
)

df_members
# Out:
#                                                links  value.id  \
# 0  [{'rel': 'self', 'href': '/Constituency/4262/R...      4262
# 1  [{'rel': 'self', 'href': '/Constituency/3972/C...      3972
# 2  [{'rel': 'self', 'href': '/Constituency/4061/G...      4061
#
#                value.name      value.startDate  value.endDate  \
# 0    Rochester and Strood  2024-05-31T00:00:00            NaN
# 1   Chatham and Aylesford  2024-05-31T00:00:00            NaN
# 2  Gillingham and Rainham  2024-05-31T00:00:00            NaN
#
#    value.currentRepresentation.member.value.id  \
# 0                                         5298
# 1                                         5220
# 2                                         5215
#
#   value.currentRepresentation.member.value.nameListAs  \
# 0                                    Edwards, Lauren
# 1                                   Osborne, Tristan
# 2                                    Khan, Naushabah
#
#   value.currentRepresentation.member.value.nameDisplayAs  \
# 0                                     Lauren Edwards
# 1                                    Tristan Osborne
# 2                                     Naushabah Khan
#
#   value.currentRepresentation.member.value.nameFullTitle  \
# 0                                  Lauren Edwards MP
# 1                                 Tristan Osborne MP
# 2                                  Naushabah Khan MP
#
#    value.currentRepresentation.member.value.nameAddressAs  ...  \
# 0                                                NaN       ...
# 1                                                NaN       ...
# 2                                                NaN       ...
#
#             value.currentRepresentation.member.links  \
# 0  [{'rel': 'self', 'href': '/Members/5298', 'met...
# 1  [{'rel': 'self', 'href': '/Members/5220', 'met...
# 2  [{'rel': 'self', 'href': '/Members/5215', 'met...
#
#   value.currentRepresentation.representation.membershipFrom  \
# 0                               Rochester and Strood
# 1                              Chatham and Aylesford
# 2                             Gillingham and Rainham
#
#   value.currentRepresentation.representation.membershipFromId  \
# 0                                               4262
# 1                                               3972
# 2                                               4061
#
#   value.currentRepresentation.representation.house  \
# 0                                                1
# 1                                                1
# 2                                                1
#
#   value.currentRepresentation.representation.membershipStartDate  \
# 0                                2024-07-04T00:00:00
# 1                                2024-07-04T00:00:00
# 2                                2024-07-04T00:00:00
#
#    value.currentRepresentation.representation.membershipEndDate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    value.currentRepresentation.representation.membershipEndReason  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    value.currentRepresentation.representation.membershipEndReasonNotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    value.currentRepresentation.representation.membershipEndReasonId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   value.currentRepresentation.representation.membershipStatus
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
# [3 rows x 45 columns]

# %%
# Get member voting


def get_member_voting(member_id):    

    url = urllib.parse.urljoin(url_base, f"/api/Members/{member_id}/Voting")

    page = 1
    
    items = []
    while url:
        params = {
            'house': 1, 
            'page': page
        }
        print(f"fetching: {url, params}")
        response = requests.get(url, params=params)
        data = response.json()

        if len(data['items']) > 0:
            items.extend(data['items'])
            page+=1
        else:
            url = None
                        
        time.sleep(5)
    
    
    return items

for member_id in df_members['value.currentRepresentation.member.value.id']:
    print(member_id)
    member_voting = get_member_voting(member_id)
    df_member_votes = (
        pd.json_normalize(member_voting)
        .to_json(f"data/representation/member_commons_votes/{member_id}.json", orient='records', index=False)
    )
# Out:
# 5298
# fetching: ('https://members-api.parliament.uk/api/Members/5298/Voting', {'house': 1, 'page': 1})
# fetching: ('https://members-api.parliament.uk/api/Members/5298/Voting', {'house': 1, 'page': 2})
# fetching: ('https://members-api.parliament.uk/api/Members/5298/Voting', {'house': 1, 'page': 3})
# fetching: ('https://members-api.parliament.uk/api/Members/5298/Voting', {'house': 1, 'page': 4})
# 5220
# fetching: ('https://members-api.parliament.uk/api/Members/5220/Voting', {'house': 1, 'page': 1})
# fetching: ('https://members-api.parliament.uk/api/Members/5220/Voting', {'house': 1, 'page': 2})
# fetching: ('https://members-api.parliament.uk/api/Members/5220/Voting', {'house': 1, 'page': 3})
# fetching: ('https://members-api.parliament.uk/api/Members/5220/Voting', {'house': 1, 'page': 4})
# 5215
# fetching: ('https://members-api.parliament.uk/api/Members/5215/Voting', {'house': 1, 'page': 1})
# fetching: ('https://members-api.parliament.uk/api/Members/5215/Voting', {'house': 1, 'page': 2})
# fetching: ('https://members-api.parliament.uk/api/Members/5215/Voting', {'house': 1, 'page': 3})
# fetching: ('https://members-api.parliament.uk/api/Members/5215/Voting', {'house': 1, 'page': 4})

# %%
# Load voting data
df_members_voting = (
    pd.concat(
        [pd.read_json(f"data/representation/member_commons_votes/{member_id}.json").assign(**{'member_id': member_id}) 
        for member_id in df_members['value.currentRepresentation.member.value.id']]
    )
    .merge(df_members, how='right', left_on='member_id', right_on='value.currentRepresentation.member.value.id')
    .rename(columns={
        'value.currentRepresentation.member.value.nameDisplayAs': 'member_name', 
        'value.id_x': 'voting_id', 
        'value.date': 'date_vote',
        'value.title': 'division_name',
        'value.divisionNumber': 'division_number'
    })
)
df_members_voting.columns
# Out:
# Index(['links_x', 'value.house', 'voting_id', 'value.inAffirmativeLobby',
#        'value.actedAsTeller', 'division_name', 'date_vote', 'division_number',
#        'value.numberInFavour', 'value.numberAgainst', 'member_id', 'links_y',
#        'value.id_y', 'value.name', 'value.startDate', 'value.endDate',
#        'value.currentRepresentation.member.value.id',
#        'value.currentRepresentation.member.value.nameListAs', 'member_name',
#        'value.currentRepresentation.member.value.nameFullTitle',
#        'value.currentRepresentation.member.value.nameAddressAs',
#        'value.currentRepresentation.member.value.latestParty.id',
#        'value.currentRepresentation.member.value.latestParty.name',
#        'value.currentRepresentation.member.value.latestParty.abbreviation',
#        'value.currentRepresentation.member.value.latestParty.backgroundColour',
#        'value.currentRepresentation.member.value.latestParty.foregroundColour',
#        'value.currentRepresentation.member.value.latestParty.isLordsMainParty',
#        'value.currentRepresentation.member.value.latestParty.isLordsSpiritualParty',
#        'value.currentRepresentation.member.value.latestParty.governmentType',
#        'value.currentRepresentation.member.value.latestParty.isIndependentParty',
#        'value.currentRepresentation.member.value.gender',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipFrom',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipFromId',
#        'value.currentRepresentation.member.value.latestHouseMembership.house',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipStartDate',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipEndDate',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipEndReason',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipEndReasonNotes',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipEndReasonId',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipStatus.statusIsActive',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipStatus.statusDescription',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipStatus.statusNotes',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipStatus.statusId',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipStatus.status',
#        'value.currentRepresentation.member.value.latestHouseMembership.membershipStatus.statusStartDate',
#        'value.currentRepresentation.member.value.thumbnailUrl',
#        'value.currentRepresentation.member.links',
#        'value.currentRepresentation.representation.membershipFrom',
#        'value.currentRepresentation.representation.membershipFromId',
#        'value.currentRepresentation.representation.house',
#        'value.currentRepresentation.representation.membershipStartDate',
#        'value.currentRepresentation.representation.membershipEndDate',
#        'value.currentRepresentation.representation.membershipEndReason',
#        'value.currentRepresentation.representation.membershipEndReasonNotes',
#        'value.currentRepresentation.representation.membershipEndReasonId',
#        'value.currentRepresentation.representation.membershipStatus'],
#       dtype='object')

# %% [markdown]
# ### 1.3 Divisions

# %%
# Final all divisions since a date
# https://www.gov.uk/government/news/state-opening-of-parliament-to-take-place-on-17-july-2024

def get_divisions_from_date(start_date='2024-07-09'):
    return_format = 'json'
    url = urllib.parse.urljoin("https://commonsvotes-api.parliament.uk/", f"/data/divisions.{return_format}/search")
    divisions = []
    skip = 0
    while url:
        params={
            'startDate': start_date,
            'skip': skip,
            'take': 25
        }
        print(f"Fetching {url} {params}")
        response = requests.get(url=url, params=params)
    
        if len(response.json()) > 0:
            divisions.extend(response.json())
            skip += 25
            time.sleep(2)
        else:
            url = None
    return divisions

divisions = get_divisions_from_date()
# Out:
# Fetching https://commonsvotes-api.parliament.uk/data/divisions.json/search {'startDate': '2024-07-09', 'skip': 0, 'take': 25}
# Fetching https://commonsvotes-api.parliament.uk/data/divisions.json/search {'startDate': '2024-07-09', 'skip': 25, 'take': 25}
# Fetching https://commonsvotes-api.parliament.uk/data/divisions.json/search {'startDate': '2024-07-09', 'skip': 50, 'take': 25}
# Fetching https://commonsvotes-api.parliament.uk/data/divisions.json/search {'startDate': '2024-07-09', 'skip': 75, 'take': 25}

# %%
df_divisions = (
        pd.DataFrame.from_records(divisions)
    )

df_divisions
# Out:
#     DivisionId                 Date   PublicationUpdated  Number  IsDeferred  \
# 0         1888  2024-12-10T16:27:00  2024-12-10T16:56:21      62       False
# 1         1887  2024-12-10T16:11:00  2024-12-10T16:29:05      61       False
# 2         1886  2024-12-10T15:56:00  2024-12-10T16:14:18      60       False
# 3         1885  2024-12-10T14:17:00  2024-12-10T14:34:38      59       False
# 4         1884  2024-12-09T20:38:00  2024-12-09T21:00:40      58       False
# ..         ...                  ...                  ...     ...         ...
# 57        1831  2024-07-25T13:08:00  2024-07-25T13:33:27       5       False
# 58        1830  2024-07-23T19:30:00  2024-07-24T19:12:05       4       False
# 59        1829  2024-07-23T19:15:00  2024-07-23T20:10:34       3       False
# 60        1828  2024-07-23T18:59:00  2024-07-24T11:30:21       2       False
# 61        1827  2024-07-22T21:59:00  2024-07-23T19:43:21       1       False
#
#    EVELType EVELCountry                                              Title  \
# 0                        Draft Home Detention Curfew and Requisite and ...
# 1                                      Finance Bill Committee New Clause 3
# 2                                     Finance Bill Committee: New Clause 2
# 3                                     Finance Bill Committee: New Clause 5
# 4                        Terrorism (Protection of Premises) Bill: New C...
# ..      ...         ...                                                ...
# 57                       The draft Criminal Justice Act 2003 (Requisite...
# 58                       King's Speech (Motion for an Address): Amendme...
# 59                       King's Speech (Motion for an Address): Amendme...
# 60                       King's Speech (Motion for an Address): Amendme...
# 61                       King's Speech (Motion for an Address): Amendme...
#
#     AyeCount  NoCount  ... DoubleMajorityNoCount  \
# 0        424      106  ...                  None
# 1        184      359  ...                  None
# 2         74      350  ...                  None
# 3        105      340  ...                  None
# 4         89      340  ...                  None
# ..       ...      ...  ...                   ...
# 57       323       81  ...                  None
# 58        85      382  ...                  None
# 59       103      363  ...                  None
# 60       117      384  ...                  None
# 61       111      390  ...                  None
#
#                                            AyeTellers  \
# 0   [{'MemberId': 4871, 'Name': 'Christian Wakefor...
# 1   [{'MemberId': 4813, 'Name': 'Richard Holden', ...
# 2   [{'MemberId': 5090, 'Name': 'Tom Morrison', 'P...
# 3   [{'MemberId': 5297, 'Name': 'Rebecca Paul', 'P...
# 4   [{'MemberId': 5297, 'Name': 'Rebecca Paul', 'P...
# ..                                                ...
# 57  [{'MemberId': 4501, 'Name': 'Gerald Jones', 'P...
# 58  [{'MemberId': 4612, 'Name': 'Jamie Stone', 'Pa...
# 59  [{'MemberId': 4357, 'Name': 'Kirsty Blackman',...
# 60  [{'MemberId': 4759, 'Name': 'Joy Morrissey', '...
# 61  [{'MemberId': 4759, 'Name': 'Joy Morrissey', '...
#
#                                             NoTellers Ayes Noes  \
# 0   [{'MemberId': 4813, 'Name': 'Richard Holden', ...   []   []
# 1   [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 2   [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 3   [{'MemberId': 4449, 'Name': 'Anna Turley', 'Pa...   []   []
# 4   [{'MemberId': 4993, 'Name': 'Keir Mather', 'Pa...   []   []
# ..                                                ...  ...  ...
# 57  [{'MemberId': 4384, 'Name': 'Mike Wood', 'Part...   []   []
# 58  [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 59  [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 60  [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 61  [{'MemberId': 4491, 'Name': 'Vicky Foxcroft', ...   []   []
#
#    FriendlyDescription FriendlyTitle NoVoteRecorded RemoteVotingStart  \
# 0                 None          None             []              None
# 1                 None          None             []              None
# 2                 None          None             []              None
# 3                 None          None             []              None
# 4                 None          None             []              None
# ..                 ...           ...            ...               ...
# 57                None          None             []              None
# 58                None          None             []              None
# 59                None          None             []              None
# 60                None          None             []              None
# 61                None          None             []              None
#
#    RemoteVotingEnd
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ..             ...
# 57            None
# 58            None
# 59            None
# 60            None
# 61            None
#
# [62 rows x 21 columns]

# %% [markdown]
# ### 3.1 Alignment

# %%
def _color_red_or_green(val):
    if val is None:
        color='blue'
    elif val == True:
        color = 'green'
    else:
        color = 'red'
    return 'color: %s' % color


(
    df_members_voting[['date_vote','member_id','member_name','voting_id', 'value.divisionNumber', 'value.inAffirmativeLobby',
       'division_name', 'value.divisionNumber', 'value.numberInFavour', 'value.numberAgainst'
    ]]
    
    .reset_index()
    .assign(**{
        'date_vote': lambda _df: pd.to_datetime(_df['date_vote']).dt.date
    })
    .pivot(index=["date_vote", "Vote"], columns=["member_name"], values=["value.inAffirmativeLobby"])
    # .pipe(lambda _df: _df.columns.get_level_values(1))
    .pipe(lambda _df: _df.set_axis( [col[1] for col in _df.columns.values], axis=1))
    # .reset_index()
    .assign(**{
        'aligned': lambda _df: _df.apply(lambda _row: _row['Lauren Edwards'] == _row['Naushabah Khan'] == _row['Tristan Osborne'], axis=1)
    })
    .loc[lambda _df: _df['aligned'] == False]
    .fillna("")
    .sort_values('date_vote', ascending=False)
).style.map(_color_red_or_green)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 12
#       7         color = 'red'
#       8     return 'color: %s' % color
#      11 (
# ---> 12     df_members_voting[['date_vote','member_id','member_name','voting_id', 'value.divisionNumber', 'value.inAffirmativeLobby',
#      13        'division_name', 'value.divisionNumber', 'value.numberInFavour', 'value.numberAgainst'
#      14     ]]
#      15
#      16     .reset_index()
#      17     .assign(**{
#      18         'date_vote': lambda _df: pd.to_datetime(_df['date_vote']).dt.date
#      19     })
#      20     .pivot(index=["date_vote", "Vote"], columns=["member_name"], values=["value.inAffirmativeLobby"])
#      21     # .pipe(lambda _df: _df.columns.get_level_values(1))
#      22     .pipe(lambda _df: _df.set_axis( [col[1] for col in _df.columns.values], axis=1))
#      23     # .reset_index()
#      24     .assign(**{
#      25         'aligned': lambda _df: _df.apply(lambda _row: _row['Lauren Edwards'] == _row['Naushabah Khan'] == _row['Tristan Osborne'], axis=1)
#      26     })
#      27     .loc[lambda _df: _df['aligned'] == False]
#      28     .fillna("")
#      29     .sort_values('date_vote', ascending=False)
#      30 ).style.map(_color_red_or_green)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['value.divisionNumber'] not in index"

# %%
# Which divisions did our local politicians not vote in?
voted_in = df_members_voting['voting_id'].unique()

df_divisions.loc[lambda _df: _df['DivisionId'].isin(voted_in)]
# Out:
#     DivisionId                 Date   PublicationUpdated  Number  IsDeferred  \
# 0         1888  2024-12-10T16:27:00  2024-12-10T16:56:21      62       False
# 1         1887  2024-12-10T16:11:00  2024-12-10T16:29:05      61       False
# 2         1886  2024-12-10T15:56:00  2024-12-10T16:14:18      60       False
# 3         1885  2024-12-10T14:17:00  2024-12-10T14:34:38      59       False
# 4         1884  2024-12-09T20:38:00  2024-12-09T21:00:40      58       False
# ..         ...                  ...                  ...     ...         ...
# 57        1831  2024-07-25T13:08:00  2024-07-25T13:33:27       5       False
# 58        1830  2024-07-23T19:30:00  2024-07-24T19:12:05       4       False
# 59        1829  2024-07-23T19:15:00  2024-07-23T20:10:34       3       False
# 60        1828  2024-07-23T18:59:00  2024-07-24T11:30:21       2       False
# 61        1827  2024-07-22T21:59:00  2024-07-23T19:43:21       1       False
#
#    EVELType EVELCountry                                              Title  \
# 0                        Draft Home Detention Curfew and Requisite and ...
# 1                                      Finance Bill Committee New Clause 3
# 2                                     Finance Bill Committee: New Clause 2
# 3                                     Finance Bill Committee: New Clause 5
# 4                        Terrorism (Protection of Premises) Bill: New C...
# ..      ...         ...                                                ...
# 57                       The draft Criminal Justice Act 2003 (Requisite...
# 58                       King's Speech (Motion for an Address): Amendme...
# 59                       King's Speech (Motion for an Address): Amendme...
# 60                       King's Speech (Motion for an Address): Amendme...
# 61                       King's Speech (Motion for an Address): Amendme...
#
#     AyeCount  NoCount  ... DoubleMajorityNoCount  \
# 0        424      106  ...                  None
# 1        184      359  ...                  None
# 2         74      350  ...                  None
# 3        105      340  ...                  None
# 4         89      340  ...                  None
# ..       ...      ...  ...                   ...
# 57       323       81  ...                  None
# 58        85      382  ...                  None
# 59       103      363  ...                  None
# 60       117      384  ...                  None
# 61       111      390  ...                  None
#
#                                            AyeTellers  \
# 0   [{'MemberId': 4871, 'Name': 'Christian Wakefor...
# 1   [{'MemberId': 4813, 'Name': 'Richard Holden', ...
# 2   [{'MemberId': 5090, 'Name': 'Tom Morrison', 'P...
# 3   [{'MemberId': 5297, 'Name': 'Rebecca Paul', 'P...
# 4   [{'MemberId': 5297, 'Name': 'Rebecca Paul', 'P...
# ..                                                ...
# 57  [{'MemberId': 4501, 'Name': 'Gerald Jones', 'P...
# 58  [{'MemberId': 4612, 'Name': 'Jamie Stone', 'Pa...
# 59  [{'MemberId': 4357, 'Name': 'Kirsty Blackman',...
# 60  [{'MemberId': 4759, 'Name': 'Joy Morrissey', '...
# 61  [{'MemberId': 4759, 'Name': 'Joy Morrissey', '...
#
#                                             NoTellers Ayes Noes  \
# 0   [{'MemberId': 4813, 'Name': 'Richard Holden', ...   []   []
# 1   [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 2   [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 3   [{'MemberId': 4449, 'Name': 'Anna Turley', 'Pa...   []   []
# 4   [{'MemberId': 4993, 'Name': 'Keir Mather', 'Pa...   []   []
# ..                                                ...  ...  ...
# 57  [{'MemberId': 4384, 'Name': 'Mike Wood', 'Part...   []   []
# 58  [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 59  [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 60  [{'MemberId': 4871, 'Name': 'Christian Wakefor...   []   []
# 61  [{'MemberId': 4491, 'Name': 'Vicky Foxcroft', ...   []   []
#
#    FriendlyDescription FriendlyTitle NoVoteRecorded RemoteVotingStart  \
# 0                 None          None             []              None
# 1                 None          None             []              None
# 2                 None          None             []              None
# 3                 None          None             []              None
# 4                 None          None             []              None
# ..                 ...           ...            ...               ...
# 57                None          None             []              None
# 58                None          None             []              None
# 59                None          None             []              None
# 60                None          None             []              None
# 61                None          None             []              None
#
#    RemoteVotingEnd
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ..             ...
# 57            None
# 58            None
# 59            None
# 60            None
# 61            None
#
# [61 rows x 21 columns]

# %%
### Winning team
df_members_voting
