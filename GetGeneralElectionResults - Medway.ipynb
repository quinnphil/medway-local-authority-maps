# %% [markdown]
# # General Election 2024 results

# %%
urls_results = {
    "Chatham and Aylesford": "https://electionresults.parliament.uk/elections/3375/candidate-results.csv",
    "Gillingham and Rainham": "https://electionresults.parliament.uk/elections/3486/candidate-results.csv",
    "Rochester and Strood": "https://electionresults.parliament.uk/elections/3728/candidate-results.csv"
    
}
# Medway Council
"""
    "https://www.medway.gov.uk/info/200812/general_election_2024/1904/general_election_2024_results",
    "https://www.medway.gov.uk/info/200812/general_election_2024/1904/general_election_2024_results/2",
    "https://www.medway.gov.uk/info/200812/general_election_2024/1904/general_election_2024_results/3"
"""
# https://electionresults.parliament.uk/elections/3375
# https://commonslibrary.parliament.uk/research-briefings/cbp-10009/
# https://electionresults.parliament.uk/general-elections/6/constituency-areas
# https://www.electoralcommission.org.uk/sites/default/files/2023-09/2023%20England%20Electoral%20data.xlsx

# https://pysal.org/tobler/notebooks/census_to_hexgrid.html

# https://www.bbc.co.uk/news/election/2024/uk/results
# Technical spec for OS boundard line data
# https://osdatahub.os.uk/downloads/open/BoundaryLine
# https://www.ordnancesurvey.co.uk/documents/product-support/tech-spec/boundary-line-technical-specification-v4.3.pdf


# Polling districts Medway
# https://www.medway.gov.uk/downloads/file/7435/existing_schedule_of_polling_districts_and_polling_places_2022

# %%
# Medway Election data
# !pip install geopandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
path_boundaries = 'data/bdline_gpkg_gb/Data/bdline_gb.gpkg'
gdf_boundaries =(
    gpd.read_file(path_boundaries, layer='polling_districts_england')
    
)
# Out:
#   Cell In[19], line 4
#     .loc[lambda _df['County'] == 'Kent County']
#                    ^
# SyntaxError: invalid syntax

# %%
(
    gdf_boundaries
    .loc[lambda _df: _df['Distric_Bo'] == 'Medway (B)']
).boundary.plot()
# Out:
# <Axes: >
